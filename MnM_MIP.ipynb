# %% [markdown]
# # Mixed Integer Programming(MIP) for the instance  'Meal Planning for the New Millennium'(MnM)

# %% [markdown]
# ## Download the library
# First install [DOcplex](https://cdn.rawgit.com/IBMDecisionOptimization/docplex-doc/2.0.15/docs/index.html) Python library if needed. Consider the scale for this problem, [CPLEX](https://www.ibm.com/analytics/cplex-optimizer) or [DOcplexcloud](https://developer.ibm.com/docloud) is needed.

# %%
import sys
try:
    import docplex.mp
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip install docplex
    else:
        # !pip install --user docplex

# %% [markdown]
# Subscribe to IBM Decision Optimization on Cloud service service if you do not want to use a local solver.
# Get the service URL and your personal API key and enter your credentials here if accurate:

# %%
url = "https://api-oaas.docloud.ibmcloud.com/job_manager/rest/v1/"
key = "api_cbbbfd41-bb59-44b1-a2c5-44dc754e8255"

# %% [markdown]
# ## Create a model instance

# %%
from docplex.mp.model import Model

MnM = Model(name='Meal Planning for the New Millennium')

# %% [markdown]
# The model for this instance is describe below
#
# \begin{align*}
# Indices: & \\
# & Person: i \in {\{1,2\}} \\
# & Day: t \in {\{1,...,5\}} \\
# & Recipes: k \in {\{1,...,K\}} \\
# Parameters: & \\
# & Available \ Time: T_{it} \\
# & Budget: B \\
# & Recipe \ price: \pi_k  \\
# & Nutrition \ Vector: A_k=(c_k,f_k,p_k,s_k,car_k)^T \\
# & Minimum \ Nutrition \ Requirements: R_l=(c_l,f_l,p_l,s_l,car_l)^T \\
# & Maximum \ Nutrition \ Requirements: R_u=(c_u,f_u,p_u,s_u,car_u)^T \\
# & Cooking \ Time: \tau_k \\
# & Ratings: r_{ik} \\
# & Filtering: F \text{ indicate the indices for recipes including allergy or dislike food} \\
# Variables: & \\
# & x_{itk} \in {\{0,1\}}  \text{ indicate whether person i cook recipe k on day t} \\
# & w: inequity \\
# \\
# \\
# \max & \sum_{j=1}^{K}\sum_{t=1}^5\sum_{i=1}^2 (r_{1k}+r_{2k}) x_{itk} -\alpha w
# \end{align*}
# subject to
# \begin{align*}
# \sum_{j=1}^{K}\sum_{t=1}^5\sum_{i=1}^2  \pi_k x_{itk} & \leq B \\
# \sum_{j=1}^{K} \tau_k x_{itk} & \leq T_{it}, \forall i \in {\{1,2\}},t \in {\{1,...,5\}} \\
# \sum_{j=1}^{K}\sum_{t=1}^5 \tau_k (x_{1tk}-x_{2tk}) & \geq -w \\
# \sum_{j=1}^{K}\sum_{t=1}^5 \tau_k (x_{1tk}-x_{2tk}) & \leq w \\
# \sum_{j=1}^{K}\sum_{t=1}^5\sum_{i=1}^2 A_k x_{itk} & \geq R_l \\
# \sum_{j=1}^{K}\sum_{t=1}^5\sum_{i=1}^2 A_k x_{itk} & \leq R_u \\
# \sum_{k=1}^K\sum_{i=1}^2  x_{itk} & = 1, \forall t \in {\{1,...,5\}} \\
# \sum_{t=1}^5\sum_{i=1}^2  x_{itk} & \leq 1, \forall k \in {\{1,...,K\}} \\
# x_{itk} & = 0, \forall i \in {\{1,2\}},t \in {\{1,...,5\}},k \in F\\
# x_{itk} & \in\{{0,1}\}, \forall i \in {\{1,2\}},t \in {\{1,...,5\}},k \in {\{1,...,K\}}
# \end{align*}

# %%
import numpy as np
import pandas as pd

# %%
rating_matrix = pd.read_csv('recipe-user-rating-after-matrix-completion.csv', index_col=False)

# %%
rating_matrix.head()
# Out:
#    X  X20.Minute.Pesto.Chicken.Pizza  X30.Minute.Sheet.Pan.Chicken.Caprese  \
# 0  0                        5.000000                              4.682655
# 1  1                        4.000000                              4.000000
# 2  2                        4.707114                              4.407471
# 3  3                        5.000000                              5.000000
# 4  4                        4.500000                              4.500000
#
#    X4.Ingredient.BBQ.Baked.Salmon  X5.Ingredient.Cheesecake  \
# 0                        4.766987                  5.000000
# 1                        5.000000                  5.000000
# 2                        5.000000                  4.586997
# 3                        5.000000                  4.870668
# 4                        4.738222                  5.000000
#
#    X5.Ingredient.Honey.BBQ.Baked.Chicken.Wings  X5.Ingredient.Pound.Cake  \
# 0                                          5.0                  3.594327
# 1                                          5.0                  3.000000
# 2                                          4.0                  1.000000
# 3                                          5.0                  5.000000
# 4                                          5.0                  3.740481
#
#    Amazing.Rosemary.Sweet.Potato.Fries  Apple.Cinnamon.Muffins  \
# 0                             4.466223                4.556360
# 1                             4.000000                5.000000
# 2                             4.211873                4.289544
# 3                             4.497715                4.577213
# 4                             4.515841                4.591708
#
#    Apple.Pie.Baked.Oatmeal  ...  Sweet.and.Salty.Candied.Bacon  \
# 0                 4.820759  ...                       4.211138
# 1                 4.000000  ...                       1.000000
# 2                 4.458705  ...                       4.000000
# 3                 4.720207  ...                       5.000000
# 4                 4.692075  ...                       5.000000
#
#    Sweet.and.Spicy.Pecans  Twice.Baked.Potatoes  Vegan.Baked.Ziti  \
# 0                4.679252              5.000000          5.679800
# 1                4.312266              5.000000          5.000000
# 2                4.440338              5.000000          5.000000
# 3                4.754628              4.506734          5.376022
# 4                4.788643              5.000000          5.000000
#
#    Vegan.Banana.Bread  Vegan.Black.Bean.Enchiladas  Vegan.Chickpea..Meatloaf.  \
# 0            5.124751                     5.057999                   5.000000
# 1            4.701904                     5.000000                   4.125224
# 2            5.000000                     5.000000                   4.169489
# 3            5.138163                     5.000000                   4.394521
# 4            5.150905                     5.060170                   4.345750
#
#    Vegan.Spinach.Lasagna  Vegetarian.Bean.and.Cheese.Taco.Casserole  \
# 0               5.000000                                   5.873637
# 1               4.281432                                   5.324161
# 2               4.394664                                   5.382821
# 3               4.693250                                   5.674733
# 4               4.000000                                   5.613377
#
#    Za.atar.Roasted.Cauliflower.Steaks.with.Bean.Salad
# 0                                           2.978791
# 1                                           2.789098
# 2                                           2.921127
# 3                                           3.171949
# 4                                           4.000000
#
# [5 rows x 126 columns]

# %%
rating_matrix.shape
# Out:
# (35, 126)

# %% [markdown]
# ## Rearrange the recipes-user-rating matrix

# %%
columns =  list(pd.read_csv('final_rating_data.csv', index_col=False).columns)

# %%
rating_matrix.columns = columns

# %%
rating_matrix.head()
# Out:
#    Unnamed: 0  20-Minute Pesto Chicken Pizza  \
# 0           0                       5.000000
# 1           1                       4.000000
# 2           2                       4.707114
# 3           3                       5.000000
# 4           4                       4.500000
#
#    30-Minute Sheet Pan Chicken Caprese  4-Ingredient BBQ Baked Salmon  \
# 0                             4.682655                       4.766987
# 1                             4.000000                       5.000000
# 2                             4.407471                       5.000000
# 3                             5.000000                       5.000000
# 4                             4.500000                       4.738222
#
#    5-Ingredient Cheesecake  5-Ingredient Honey-BBQ Baked Chicken Wings  \
# 0                 5.000000                                         5.0
# 1                 5.000000                                         5.0
# 2                 4.586997                                         4.0
# 3                 4.870668                                         5.0
# 4                 5.000000                                         5.0
#
#    5-Ingredient Pound Cake  Amazing Rosemary Sweet Potato Fries  \
# 0                 3.594327                             4.466223
# 1                 3.000000                             4.000000
# 2                 1.000000                             4.211873
# 3                 5.000000                             4.497715
# 4                 3.740481                             4.515841
#
#    Apple Cinnamon Muffins  Apple Pie Baked Oatmeal   ...  \
# 0                4.556360                  4.820759  ...
# 1                5.000000                  4.000000  ...
# 2                4.289544                  4.458705  ...
# 3                4.577213                  4.720207  ...
# 4                4.591708                  4.692075  ...
#
#    Sweet and Salty Candied Bacon  Sweet and Spicy Pecans  \
# 0                       4.211138                4.679252
# 1                       1.000000                4.312266
# 2                       4.000000                4.440338
# 3                       5.000000                4.754628
# 4                       5.000000                4.788643
#
#    Twice Baked Potatoes  Vegan Baked Ziti  Vegan Banana Bread  \
# 0              5.000000          5.679800            5.124751
# 1              5.000000          5.000000            4.701904
# 2              5.000000          5.000000            5.000000
# 3              4.506734          5.376022            5.138163
# 4              5.000000          5.000000            5.150905
#
#    Vegan Black Bean Enchiladas  Vegan Chickpea "Meatloaf"  \
# 0                     5.057999                   5.000000
# 1                     5.000000                   4.125224
# 2                     5.000000                   4.169489
# 3                     5.000000                   4.394521
# 4                     5.060170                   4.345750
#
#    Vegan Spinach Lasagna  Vegetarian Bean and Cheese Taco Casserole  \
# 0               5.000000                                   5.873637
# 1               4.281432                                   5.324161
# 2               4.394664                                   5.382821
# 3               4.693250                                   5.674733
# 4               4.000000                                   5.613377
#
#    Za'atar-Roasted Cauliflower Steaks with Bean Salad
# 0                                           2.978791
# 1                                           2.789098
# 2                                           2.921127
# 3                                           3.171949
# 4                                           4.000000
#
# [5 rows x 126 columns]

# %%
recipes = pd.read_csv('recipe_info.csv', index_col=False)

# %%
recipes.head()
# Out:
#    Unnamed: 0                                        title  rating  time  \
# 0           1                  Four-Cheese Baked Spaghetti     4.5  75.0
# 1           3             Creamy Spinach Stuffed Mushrooms     4.5  33.0
# 2           7             Best Ever Chocolate Chip Muffins     4.5  41.0
# 3           8  Sheet Pan Yellow Squash and Chicken Sausage     4.5  42.0
# 4           9       Hearty Italian Beef and Vegetable Soup     4.5  40.0
#
#    price  calories  sodium   fat  protein  carbs  \
# 0  38.35     570.0  1230.0  28.0       31     51
# 1  17.99      70.0   180.0   5.0        3      3
# 2  30.70     270.0   270.0  14.0        4     34
# 3  20.08     340.0   960.0  24.0       22     10
# 4  23.10     240.0   920.0   7.0       27     19
#
#                                      personal_rating  \
# 0  [['Kaitlin Judd', 3.0], ['Em Spreadborough', 5...
# 1  [['Avery', 1.0], ['Ischa Bremer', 4.0], ['Kiau...
# 2  [['Sophia', 5.0], ['Heidi Crosgrove-Trobaugh',...
# 3  [['Holly Lynch', 5.0], ['Amy J.', 5.0], ['Cath...
# 4  [['Isabella', 5.0], ['Rejeana Black', 5.0], ['...
#
#                                          ingredients  \
# 0  ['spaghetti ', 'lowmoisture ricotta cheese ', ...
# 1  ['cremini mushrooms ', 'cream cheese ', 'grate...
# 2  ['unsalted butter ', 'granulated sugar ', 'lig...
# 3  ['yellow summer squash ', 'cooked chicken saus...
# 4  ['medium onion ', 'garlic cloves ', 'large car...
#
#                                                  url
# 0  https://www.yummly.com/recipe/Four-Cheese-Bake...
# 1  https://www.yummly.com/recipe/Creamy-Spinach-S...
# 2  https://www.yummly.com/recipe/Best-Ever-Chocol...
# 3  https://www.yummly.com/recipe/Sheet-Pan-Yellow...
# 4  https://www.yummly.com/recipe/Hearty-Italian-B...

# %%
title = recipes.title

# %%
rating_matrix = rating_matrix[title]

# %%
rating_matrix.head()
# Out:
#    Four-Cheese Baked Spaghetti  Creamy Spinach Stuffed Mushrooms  \
# 0                     5.000000                          3.687671
# 1                     4.588172                          3.423826
# 2                     5.000000                          1.000000
# 3                     4.999481                          5.000000
# 4                     5.000000                          3.887457
#
#    Best Ever Chocolate Chip Muffins  \
# 0                          3.333951
# 1                          3.120542
# 2                          3.267050
# 3                          3.546508
# 4                          3.627057
#
#    Sheet Pan Yellow Squash and Chicken Sausage  \
# 0                                     5.913462
# 1                                     5.000000
# 2                                     5.313481
# 3                                     5.550495
# 4                                     5.431040
#
#    Hearty Italian Beef and Vegetable Soup  Loaded Baked Potatoes  \
# 0                                4.276111               4.307912
# 1                                3.950582               3.969670
# 2                                4.078932               4.087140
# 3                                4.377511               4.376049
# 4                                4.420124               4.406919
#
#    Soft and Chewy Keto “Sugar” Cookies  Amazing Rosemary Sweet Potato Fries  \
# 0                             3.000000                             4.466223
# 1                             5.000000                             4.000000
# 2                             4.305855                             4.211873
# 3                             4.000000                             4.497715
# 4                             5.000000                             4.515841
#
#    Farmers' Market Vegetable Bake with Sharp Cheddar and Parmesan  \
# 0                                           4.549404
# 1                                           4.101115
# 2                                           4.120461
# 3                                           5.000000
# 4                                           4.246234
#
#    Oven Baked BBQ Baby Back Ribs  ...  Easy Sweet Potatoes Au Gratin  \
# 0                       4.903512  ...                       5.000000
# 1                       5.000000  ...                       4.677771
# 2                       4.617607  ...                       4.789638
# 3                       4.927861  ...                       5.104416
# 4                       4.944136  ...                       5.113198
#
#    Savory Keto Breakfast Cookies  Sweet and Salty Candied Bacon  \
# 0                       4.987605                       4.211138
# 1                       4.560406                       1.000000
# 2                       4.655498                       4.000000
# 3                       4.948878                       5.000000
# 4                       4.942924                       5.000000
#
#    Sheet Pan Honey Mustard Pork Chops with Roasted Veggies  \
# 0                                           4.000000
# 1                                           5.000000
# 2                                           3.000000
# 3                                           4.076175
# 4                                           4.073033
#
#    Vegan Spinach Lasagna  Italian Sausage-Stuffed Mushrooms  \
# 0               5.000000                           5.000000
# 1               4.281432                           3.919499
# 2               4.394664                           4.005509
# 3               4.693250                           4.261797
# 4               4.000000                           4.261130
#
#    Vegetarian Bean and Cheese Taco Casserole  \
# 0                                   5.873637
# 1                                   5.324161
# 2                                   5.382821
# 3                                   5.674733
# 4                                   5.613377
#
#    Easy Honey-Mustard Chicken Thighs  Garlic Roasted Broccoli  \
# 0                           5.000000                 5.000000
# 1                           5.000000                 5.000000
# 2                           4.000000                 5.000000
# 3                           4.658993                 4.898368
# 4                           4.667516                 4.893291
#
#    Crispy Panko-Parmesan Chicken Breasts
# 0                               5.000000
# 1                               4.000000
# 2                               4.197244
# 3                               5.000000
# 4                               4.000000
#
# [5 rows x 125 columns]

# %% [markdown]
# ## Ingredients Filter

# %%
allergy = "salmon"
picky = "peanut" 
desserts = ["muffins","cookies","cake","brownies","chocolate","fries", "bread", "toast"]

# %%
matching = recipes[recipes.ingredients.str.contains(allergy, case=False) | recipes.ingredients.str.contains(picky, case=False)]

# %%
for dessert in desserts:
    matching = pd.concat([recipes[recipes.title.str.contains(dessert, case=False)],matching])

# %%
matching.sort_index(inplace=True)

# %%
matching.head()
# Out:
#     Unnamed: 0                                     title  rating  time  price  \
# 2            7          Best Ever Chocolate Chip Muffins     4.5  41.0  30.70
# 2            7          Best Ever Chocolate Chip Muffins     4.5  41.0  30.70
# 6           14       Soft and Chewy Keto “Sugar” Cookies     4.5  23.0  22.04
# 7           17       Amazing Rosemary Sweet Potato Fries     4.5  30.0   5.44
# 11          22  Healthy Salmon & Veggie Sheet Pan Dinner     4.5  40.0  33.46
#
#     calories  sodium   fat  protein  carbs  \
# 2      270.0   270.0  14.0        4     34
# 2      270.0   270.0  14.0        4     34
# 6      240.0   180.0  23.0        6      6
# 7      130.0   360.0   3.5        3     24
# 11     500.0   270.0  11.0       40     69
#
#                                       personal_rating  \
# 2   [['Sophia', 5.0], ['Heidi Crosgrove-Trobaugh',...
# 2   [['Sophia', 5.0], ['Heidi Crosgrove-Trobaugh',...
# 6   [['Tamara Canion', 5.0], ['Jason T.', 3.0], ['...
# 7   [['Yusuf', 5.0], ['Elaine', 5.0], ['Nick', 5.0...
# 11  [['Abigail Clark', 4.0], ['Tyler Binkley', 5.0...
#
#                                           ingredients  \
# 2   ['unsalted butter ', 'granulated sugar ', 'lig...
# 2   ['unsalted butter ', 'granulated sugar ', 'lig...
# 6   ['unsalted butter ', 'full fat cream cheese ',...
# 7   ['sweet potatoes ', 'olive oil ', 'salt ', 'bl...
# 11  ['salmon ', 'baby potatoes ', 'asparagus ', 's...
#
#                                                   url
# 2   https://www.yummly.com/recipe/Best-Ever-Chocol...
# 2   https://www.yummly.com/recipe/Best-Ever-Chocol...
# 6   https://www.yummly.com/recipe/Soft-and-Chewy-K...
# 7   https://www.yummly.com/recipe/Amazing-Rosemary...
# 11  https://www.yummly.com/recipe/Healthy-Salmon-_...

# %%
filtering = list(matching.index)

# %% [markdown]
# ## Define the variables

# %%
# x_{itk} are binary variable
x = {(i,t,k): MnM.binary_var(name='x_{0}_{1}_{2}'.format(i,t,k)) for i in range(2) for t in range(5) for k in range(recipes.shape[0])}

# %%
# time inequality
w = MnM.continuous_var(name='w', lb=0)

# %% [markdown]
# ## Define the parameters

# %%
# recipe matrix 
K = recipes.shape[0] #number of recipes
T = [[200,50,100,50,200],[0,100,100,100,100]]

#rating for user 0 and user 1
rating = rating_matrix.iloc[0:2, -K:].values.tolist()

calories = recipes.calories
protein = recipes.protein
fat = recipes.fat
sodium = recipes.sodium
carbs = recipes.carbs

price = recipes.price

tau = recipes.time

# lower(1) and upper(2) bound of nutrient
c_bound=[1200, 3000]
p_bound= [25 ,88]
f_bound=[22 , 39]
s_bound= [2200 ,2400]
car_bound= [112, 163]
B = 120 #budget

# parameter for objective
alpha = 0.1

# %% [markdown]
# ## Define the constraints

# %%
# five meals constraints, one meal per day
for t in range(5):
    MnM.add_constraint(MnM.sum(x[i,t,k] for i in range(2) for k in range(K)) == 1, ctname = 'subject to five_meals_total')


# nutrition lower bound
MnM.add_constraint(MnM.sum(calories[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= c_bound[0])
MnM.add_constraint(MnM.sum(protein[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= p_bound[0])
MnM.add_constraint(MnM.sum(fat[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= f_bound[0])
MnM.add_constraint(MnM.sum(sodium[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= s_bound[0])
MnM.add_constraint(MnM.sum(carbs[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= car_bound[0])

# nutrition upper bound
MnM.add_constraint(MnM.sum(calories[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= c_bound[1] )
MnM.add_constraint(MnM.sum(protein[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= p_bound[1] )
MnM.add_constraint(MnM.sum(fat[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= f_bound[1] )
MnM.add_constraint(MnM.sum(sodium[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= s_bound[1] )
MnM.add_constraint(MnM.sum(carbs[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= s_bound[1] )

#budget constraint
MnM.add_constraint(MnM.sum(price[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= B  )

        
# schedule time inequalities
MnM.add_constraint(MnM.sum(tau[k]* (x[0,t,k] - x[1,t,k]) for t in range(5) for k in range(K)) <= w)
MnM.add_constraint(MnM.sum(tau[k]* (x[0,t,k] - x[1,t,k]) for t in range(5) for k in range(K)) >= -w)

        
# schedule date constraint
for i in range(2):
    for t in range(5):
        MnM.add_constraint(MnM.sum(x[i,t,k] * tau[k] for k in range(K)) <= T[i][t])  
        
# Diversity constraint
for k in range(K):
    MnM.add_constraint(MnM.sum(x[i,t,k] for i in range(2) for t in range(5)) <= 1)

# Ingredients Filter
for i in range(2):
    for t in range(5):
        for k in filtering:
            MnM.add_constraint(x[i,t,k] == 0)

# %% [markdown]
# ## Define the objective function

# %%
MnM.maximize(MnM.sum((rating[0][k]+rating[1][k])*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) - alpha*w)

# %% [markdown]
# ## Solve the problem

# %%
MnM.print_information()
# Out:
# Model: Meal Planning for the New Millennium
#  - number of variables: 1251
#    - binary=1250, integer=0, continuous=1
#  - number of constraints: 563
#    - linear=563
#  - parameters: defaults
#  - problem type is: MILP

# %%
MnMs= MnM.solve(url=url, key=key, log_output=True)
assert MnMs
MnM.print_solution()
# Out:
# [2020-05-08T23:57:20Z, INFO] CPLEX version 12090000
# [2020-05-08T23:57:20Z, INFO] Parameter file:
# [2020-05-08T23:57:20Z, INFO] # -- This content is generated by DOcplex
# [2020-05-08T23:57:20Z, INFO] CPLEX Parameter File Version 12.10.0.0
# [2020-05-08T23:57:20Z, INFO] # --- end of generated prm data ---
# [2020-05-08T23:57:20Z, WARN] Warning:  CPLEX version found in file python_meal_planning_for_the_new_millennium.prm (12.10.0.0) does not match
# [2020-05-08T23:57:20Z, WARN]           this CPLEX version (12.9.0.0).
# [2020-05-08T23:57:20Z, WARN] Changed parameter CPX_PARAM_THREADS from 0 to 10
# [2020-05-08T23:57:20Z, INFO] Param[1,067] = 10
# [2020-05-08T23:57:20Z, INFO] Param[1,130] = utf-8
# [2020-05-08T23:57:20Z, INFO] Param[1,132] = -1
# [2020-05-08T23:57:20Z, INFO] CPXPARAM_Threads                                 10
# [2020-05-08T23:57:20Z, INFO] CPXPARAM_Output_CloneLog                         -1
# [2020-05-08T23:57:20Z, INFO] CPXPARAM_Read_APIEncoding                        "utf-8"
# [2020-05-08T23:57:20Z, INFO] Tried aggregator 1 time.
# [2020-05-08T23:57:20Z, INFO] MIP Presolve eliminated 463 rows and 552 columns.
# [2020-05-08T23:57:20Z, INFO] MIP Presolve modified 6929 coefficients.
# [2020-05-08T23:57:20Z, INFO] Reduced MIP has 100 rows, 699 columns, and 9539 nonzeros.
# [2020-05-08T23:57:20Z, INFO] Reduced MIP has 698 binaries, 0 generals, 0 SOSs, and 0 indicators.
# [2020-05-08T23:57:20Z, INFO] Presolve time = 0.03 sec. (18.56 ticks)
# [2020-05-08T23:57:20Z, INFO] Found incumbent of value 35.116520 after 0.05 sec. (31.44 ticks)
# [2020-05-08T23:57:20Z, INFO] Probing time = 0.01 sec. (4.78 ticks)
# [2020-05-08T23:57:20Z, INFO] Tried aggregator 1 time.
# [2020-05-08T23:57:21Z, INFO] Reduced MIP has 100 rows, 699 columns, and 9539 nonzeros.
# [2020-05-08T23:57:21Z, INFO] Reduced MIP has 698 binaries, 1 generals, 0 SOSs, and 0 indicators.
# [2020-05-08T23:57:21Z, INFO] Presolve time = 0.01 sec. (5.93 ticks)
# [2020-05-08T23:57:21Z, INFO] Probing time = 0.01 sec. (4.78 ticks)
# [2020-05-08T23:57:21Z, INFO] Clique table members: 495.
# [2020-05-08T23:57:21Z, INFO] MIP emphasis: balance optimality and feasibility.
# [2020-05-08T23:57:21Z, INFO] MIP search method: dynamic search.
# [2020-05-08T23:57:21Z, INFO] Parallel mode: deterministic, using up to 10 threads.
# [2020-05-08T23:57:21Z, INFO] Root relaxation solution time = 0.00 sec. (3.26 ticks)
# [2020-05-08T23:57:21Z, INFO]
# [2020-05-08T23:57:21Z, INFO]         Nodes                                         Cuts/
# [2020-05-08T23:57:21Z, INFO]    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
# [2020-05-08T23:57:21Z, INFO]
# [2020-05-08T23:57:21Z, INFO] *     0+    0                           35.1165     6174.7186              ---
# [2020-05-08T23:57:21Z, INFO]       0     0       52.5112    11       35.1165       52.5112       73   49.53%
# [2020-05-08T23:57:21Z, INFO]       0     0       52.2029    12       35.1165      Cuts: 11       87   48.66%
# [2020-05-08T23:57:21Z, INFO]       0     0       52.2029    15       35.1165       Cuts: 7       95   48.66%
# [2020-05-08T23:57:21Z, INFO] *     0+    0                           47.4261       52.2029            10.07%
# [2020-05-08T23:57:21Z, INFO] *     0+    0                           48.6185       52.2029             7.37%
# [2020-05-08T23:57:21Z, INFO] *     0+    0                           49.8630       52.2029             4.69%
# [2020-05-08T23:57:21Z, INFO]
# [2020-05-08T23:57:21Z, INFO] Repeating presolve.
# [2020-05-08T23:57:21Z, INFO] Tried aggregator 1 time.
# [2020-05-08T23:57:21Z, INFO] MIP Presolve eliminated 35 rows and 292 columns.
# [2020-05-08T23:57:21Z, INFO] MIP Presolve modified 971 coefficients.
# [2020-05-08T23:57:21Z, INFO] Reduced MIP has 65 rows, 407 columns, and 5455 nonzeros.
# [2020-05-08T23:57:21Z, INFO] Reduced MIP has 406 binaries, 1 generals, 0 SOSs, and 0 indicators.
# [2020-05-08T23:57:21Z, INFO] Presolve time = 0.01 sec. (4.42 ticks)
# [2020-05-08T23:57:22Z, INFO] Probing time = 0.03 sec. (2.80 ticks)
# [2020-05-08T23:57:22Z, INFO] Tried aggregator 1 time.
# [2020-05-08T23:57:22Z, INFO] Reduced MIP has 65 rows, 407 columns, and 5455 nonzeros.
# [2020-05-08T23:57:22Z, INFO] Reduced MIP has 406 binaries, 1 generals, 0 SOSs, and 0 indicators.
# [2020-05-08T23:57:22Z, INFO] Presolve time = 0.01 sec. (2.99 ticks)
# [2020-05-08T23:57:22Z, INFO] Represolve time = 0.05 sec. (12.90 ticks)
# [2020-05-08T23:57:22Z, INFO] Probing time = 0.00 sec. (2.80 ticks)
# [2020-05-08T23:57:22Z, INFO] Clique table members: 53.
# [2020-05-08T23:57:22Z, INFO] MIP emphasis: balance optimality and feasibility.
# [2020-05-08T23:57:22Z, INFO] MIP search method: dynamic search.
# [2020-05-08T23:57:22Z, INFO] Parallel mode: deterministic, using up to 10 threads.
# [2020-05-08T23:57:22Z, INFO] Root relaxation solution time = 0.00 sec. (2.10 ticks)
# [2020-05-08T23:57:22Z, INFO]
# [2020-05-08T23:57:22Z, INFO]         Nodes                                         Cuts/
# [2020-05-08T23:57:22Z, INFO]    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
# [2020-05-08T23:57:22Z, INFO]
# [2020-05-08T23:57:22Z, INFO] *     0+    0                           49.8630       52.2029             4.69%
# [2020-05-08T23:57:22Z, INFO]       0     0       52.2029    10       49.8630       52.2029      168    4.69%
# [2020-05-08T23:57:22Z, INFO]       0     0       52.2029    16       49.8630       Cuts: 9      177    4.69%
# [2020-05-08T23:57:22Z, INFO]       0     2       52.2029    10       49.8630       52.2029      177    4.69%
# [2020-05-08T23:57:22Z, INFO] Elapsed time = 0.96 sec. (227.57 ticks, tree = 0.02 MB, solutions = 4)
# [2020-05-08T23:57:23Z, INFO]    5698  2208       51.7949     9       49.8630       51.7702    24868    3.82%
# [2020-05-08T23:57:23Z, INFO]   11763  2976       51.6159    10       49.8630       51.6396    41156    3.56%
# [2020-05-08T23:57:24Z, INFO]   14777  3460        cutoff             49.8630       51.3675    62504    3.02%
# [2020-05-08T23:57:24Z, INFO]
# [2020-05-08T23:57:24Z, INFO] GUB cover cuts applied:  5
# [2020-05-08T23:57:24Z, INFO] Cover cuts applied:  327
# [2020-05-08T23:57:24Z, INFO] Mixed integer rounding cuts applied:  5
# [2020-05-08T23:57:24Z, INFO] Zero-half cuts applied:  2
# [2020-05-08T23:57:24Z, INFO] Gomory fractional cuts applied:  4
# [2020-05-08T23:57:24Z, INFO]
# [2020-05-08T23:57:24Z, INFO] Root node processing (before b&c):
# [2020-05-08T23:57:24Z, INFO]   Real time             =    0.96 sec. (227.66 ticks)
# [2020-05-08T23:57:24Z, INFO] Parallel b&c, 10 threads:
# [2020-05-08T23:57:24Z, INFO]   Real time             =    2.66 sec. (1098.94 ticks)
# [2020-05-08T23:57:24Z, INFO]   Sync time (average)   =    0.55 sec.
# [2020-05-08T23:57:24Z, INFO]   Wait time (average)   =    0.01 sec.
# [2020-05-08T23:57:24Z, INFO]                           ------------
# [2020-05-08T23:57:24Z, INFO] Total (root+branch&cut) =    3.62 sec. (1326.60 ticks)
# [2020-05-08T23:57:24Z, INFO] Incumbent solution:
# [2020-05-08T23:57:24Z, INFO] MILP objective                                 4.9863022888e+01
# [2020-05-08T23:57:24Z, INFO] MILP solution norm |x| (Total, Max)            5.00000e+00  1.00000e+00
# [2020-05-08T23:57:24Z, INFO] MILP solution error (Ax=b) (Total, Max)        7.10543e-15  7.10543e-15
# [2020-05-08T23:57:24Z, INFO] MILP x bound error (Total, Max)                0.00000e+00  0.00000e+00
# [2020-05-08T23:57:24Z, INFO] MILP x integrality error (Total, Max)          0.00000e+00  0.00000e+00
# [2020-05-08T23:57:24Z, INFO] MILP slack bound error (Total, Max)            0.00000e+00  0.00000e+00
# [2020-05-08T23:57:24Z, INFO] integer optimal, tolerance (102)
# objective: 49.863
#   x_0_0_37=1
#   x_0_1_122=1
#   x_0_2_123=1
#   x_1_3_59=1
#   x_1_4_73=1

# %%
results = pd.DataFrame(columns=['person','day','title','url','price','calories','time'])

# %%
count = 0
for i in range(2):
    for t in range(5):
        for k in range(K):
            if MnM.solution.get_value(x[i,t,k]):
                results.loc[count] = [i+1,t+1,recipes.loc[k].title,recipes.loc[k].url,recipes.loc[k].price,recipes.loc[k].calories,recipes.loc[k].time]
                count+=1

# %%
pd.set_option('display.max_colwidth', None)
results
# Out:
#   person day                              title  \
# 0      1   1          Vegan Chickpea "Meatloaf"
# 1      1   2  Easy Honey-Mustard Chicken Thighs
# 2      1   3            Garlic Roasted Broccoli
# 3      2   4        Vegan Black Bean Enchiladas
# 4      2   5                   Vegan Baked Ziti
#
#                                                                        url  \
# 0          https://www.yummly.com/recipe/Vegan-Chickpea-_Meatloaf_-9083673
# 1  https://www.yummly.com/recipe/Easy-Honey-Mustard-Chicken-Thighs-9029460
# 2            https://www.yummly.com/recipe/Garlic-Roasted-Broccoli-2684142
# 3        https://www.yummly.com/recipe/Vegan-Black-Bean-Enchiladas-9116010
# 4                   https://www.yummly.com/recipe/Vegan-Baked-Ziti-2684090
#
#    price  calories  time
# 0  32.35     380.0  75.0
# 1  19.60     310.0  30.0
# 2   7.47     130.0  30.0
# 3  24.05     100.0  60.0
# 4  34.57     360.0  75.0
